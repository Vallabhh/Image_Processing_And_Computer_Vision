# %% [markdown]
# <a href="https://colab.research.google.com/github/Vallabhh/Image_Processing_And_Computer_Vision/blob/main/IPCV_1_Lab_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Contrast Stretching**

# %%
import cv2
import matplotlib.pyplot as plt
from google.colab.patches import cv2_imshow

# %%
def calculate_gray_min_max(img):
  r_min = 100000
  r_max = -100000

  row , col = img.shape[0],img.shape[1]

  for i in range(0,row-1):
   for j in range(0,col-1):
     pixel = img[i,j]

     if(pixel<r_min):
        r_min = pixel
     if(pixel>r_max):
        r_max = pixel

  return r_min,r_max

# %%
def contrast_stretching_gray(img,l,m,n,a,b):
  row , col  = img.shape[0],img.shape[1]

  for i in range(0,row-1):
   for j in range(0,col-1):
    pixel = img[i,j]
    
    if(pixel<=a):
      pixel = l*pixel
  
    if(a<pixel<=b):
      pixel = m*(pixel-a) + l*a

    else:
      pixel = n*(pixel-b) + m*(b-a) + l*a


    img[i,j] = pixel

  return img

# %%
gray_img = cv2.imread('/content/lowcontrast.jpg',0)

# %%
cv2_imshow(gray_img)
# Out:
# <PIL.Image.Image image mode=L size=600x480 at 0x7F04C0C7FA60>

# %%
r_gray_min ,r_gray_max = calculate_gray_min_max(gray_img)
print("R_min of gray input is : ",r_gray_min)
print("R_max of gray output is : ",r_gray_max)
# Out:
# R_min of gray input is :  36
# R_max of gray output is :  255

# %% [markdown]
# **l and m <1 && n>1**

# %%
new_img = contrast_stretching_gray(gray_img,40,200,0.6,1.2,0.8)

# %%
cv2_imshow(new_img)
# Out:
# <PIL.Image.Image image mode=L size=600x480 at 0x7F04C0BDF580>

# %%
r_gray_min ,r_gray_max = calculate_gray_min_max(new_img)
print("R_min of gray input is : ",r_gray_min)
print("R_max of gray output is : ",r_gray_max)
# Out:
# R_min of gray input is :  0
# R_max of gray output is :  255

# %% [markdown]
# **l,n,m <1**

# %%
new_img = contrast_stretching_gray(gray_img,100,200,1.4,0.4,1.6)

# %%
cv2_imshow(new_img)
# Out:
# <PIL.Image.Image image mode=L size=600x480 at 0x7F04C0BDF520>

# %%
r_gray_min ,r_gray_max = calculate_gray_min_max(new_img)
print("R_min of gray input is : ",r_gray_min)
print("R_max of gray output is : ",r_gray_max)
# Out:
# R_min of gray input is :  1
# R_max of gray output is :  255

# %% [markdown]
# **Dynamic Range Compression**

# %%
gray_img = cv2.imread('/content/lowcontrast.jpg',0)

# %%
cv2_imshow(gray_img)
# Out:
# <PIL.Image.Image image mode=L size=600x480 at 0x7F04C0C0AD60>

# %%
r_min,r_max = calculate_gray_min_max(gray_img)

# %%
print("r_min is : ",r_min)
print("r_max is : ",r_max)
# Out:
# r_min is :  36
# r_max is :  255

# %%
import math

# %%
def Dynamic_Range_Compression(img,c):
  row,col = img.shape[0],img.shape[1]

  for i in range(row-1):
    for j in range(col-1):


      pixel = img[i,j]

      pixel = c*math.log(pixel + 1)

      img[i,j] = pixel

  return img

# %%
dyn_cmp_img = Dynamic_Range_Compression(gray_img,40)

# %%
cv2_imshow(dyn_cmp_img)
# Out:
# <PIL.Image.Image image mode=L size=600x480 at 0x7F04C0397220>

# %%
r_min,r_max = calculate_gray_min_max(dyn_cmp_img)

# %%
print("r_min is : ",r_min)
print("r_max is : ",r_max)
# Out:
# r_min is :  144
# r_max is :  221

# %% [markdown]
# **Power Law Transformation**

# %%
gray_img = cv2.imread('/content/lowcontrast.jpg',0)

# %%
cv2_imshow(gray_img)
# Out:
# <PIL.Image.Image image mode=L size=600x480 at 0x7F04C0390A30>

# %%
r_min,r_max = calculate_gray_min_max(gray_img)
print("r_min is : ",r_min)
print("r_max is : ",r_max)
# Out:
# r_min is :  36
# r_max is :  255

# %%
def Power_Law_Transformation(img,gamma):
  row,col = img.shape[0],img.shape[1]

  for i in range(row-1):
    for j in range(col-1):


      pixel = img[i,j]

      pixel = pixel**gamma

      img[i,j] = pixel

  return img

# %% [markdown]
# **Gamma<1**

# %%
gamma1_img = Power_Law_Transformation(gray_img,0.6)

# %%
cv2_imshow(gamma1_img)
# Out:
# <PIL.Image.Image image mode=L size=600x480 at 0x7F04C0BDF400>

# %%
r_min,r_max = calculate_gray_min_max(gamma1_img)
print("r_min is : ",r_min)
print("r_max is : ",r_max)
# Out:
# r_min is :  8
# r_max is :  27

# %% [markdown]
# **Gamma>1**

# %%
gamma2_img = Power_Law_Transformation(gray_img,1.2)

# %%
cv2_imshow(gamma2_img)
# Out:
# <PIL.Image.Image image mode=L size=600x480 at 0x7F04C0390AF0>

# %%
r_min,r_max = calculate_gray_min_max(gamma2_img)
print("r_min is : ",r_min)
print("r_max is : ",r_max)
# Out:
# r_min is :  12
# r_max is :  52
